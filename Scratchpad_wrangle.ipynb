# %% [markdown]
# State of Religion

# %% [markdown]
# Steps to go through in this Project
#
# **- Wrangle (Acquisition and Prep)   <-- We are here**
# - Explorattion
# - Evaluating Regression
# - Feature Engineering

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel("U_S_Religion_Census_2010 _clean_data.xlsx")

# %%
#Take a look at the data
df.head()
# Out:
#    State Name  Total Number of Congregations  Total Number of Adherents  \
# 0     Alabama                          10514                    3007553
# 1      Alaska                           1246                     240833
# 2     Arizona                           4673                    2379928
# 3    Arkansas                           6697                    1614357
# 4  California                          23558                   16765751
#
#    Rates of Adherence per 1,000 Population  % of Adherents  \
# 0                                   629.23         0.62923
# 1                                   339.09         0.33909
# 2                                   372.33         0.37233
# 3                                   553.64         0.55364
# 4                                   450.04         0.45004
#
#    % of Adults Who Are “Highly Religious”
# 0                                    0.77
# 1                                    0.45
# 2                                    0.53
# ...

# %%
#Take a look at the tail
df.tail()
# Out:
#        State Name  Total Number of Congregations  Total Number of Adherents  \
# 46       Virginia                          10088                    3586592
# 47     Washington                           6114                    2328005
# 48  West Virginia                           4413                     658313
# 49      Wisconsin                           6078                    3047442
# 50        Wyoming                            948                     223074
#
#     Rates of Adherence per 1,000 Population  % of Adherents  \
# 46                                   448.27         0.44827
# 47                                   346.20         0.34620
# 48                                   355.27         0.35527
# 49                                   535.86         0.53586
# 50                                   395.78         0.39578
#
#     % of Adults Who Are “Highly Religious”
# 46                                    0.61
# 47                                    0.45
# ...

# %%
#get a sense of the data size
df.shape
# Out:
# (51, 6)

# %%
#look at the data
df.describe()
# Out:
#        Total Number of Congregations  Total Number of Adherents  \
# count                      51.000000               5.100000e+01
# mean                     6762.627451               2.952878e+06
# std                      5847.958375               3.305561e+06
# min                       609.000000               2.103910e+05
# 25%                      2123.000000               7.299840e+05
# 50%                      5557.000000               2.226379e+06
# 75%                      9291.000000               3.554468e+06
# max                     27848.000000               1.676575e+07
#
#        Rates of Adherence per 1,000 Population  % of Adherents  \
# count                                51.000000       51.000000
# mean                                484.743333        0.484743
# std                                 102.764459        0.102764
# min                                 276.310000        0.276310
# 25%                                 404.455000        0.404455
# ...

# %%
#look at the datatypes
df.dtypes
# Out:
# State Name                                  object
# Total Number of Congregations                int64
# Total Number of Adherents                    int64
# Rates of Adherence per 1,000 Population    float64
# % of Adherents                             float64
# % of Adults Who Are “Highly Religious”     float64
# dtype: object

# %% [markdown]
# let's replace all the spaces in the coloumns with underscores

# %%
df.columns = df.columns.str.replace(" ", "_")

# %% [markdown]
# and let's get rid of the comma in 1000

# %%
df.columns = df.columns.str.replace(",", "")

# %% [markdown]
# This data was brought dowloaded cleaned so we can write our wrangle.py file

# %%
def wrangle_religion():
    """
    This is to bring in our US Religion Census data from 2010
    """
    df = pd.read_excel("U_S_Religion_Census_2010 _clean_data.xlsx")
    df.columns = df.columns.str.replace(" ", "_")
    df.columns = df.columns.str.replace(",", "")
    return df

# %%
df1 = wrangle_religion()

# %%
df1
# Out:
#               State_Name  Total_Number_of_Congregations  \
# 0                Alabama                          10514
# 1                 Alaska                           1246
# 2                Arizona                           4673
# 3               Arkansas                           6697
# 4             California                          23558
# 5               Colorado                           4188
# 6            Connecticut                           2597
# 7               Delaware                            831
# 8   District of Columbia                            609
# 9                Florida                          15611
# 10               Georgia                          12292
# 11                Hawaii                           1314
# 12                 Idaho                           2427
# 13              Illinois                          12453
# 14               Indiana                           9061
# 15                  Iowa                           5107
# ...
